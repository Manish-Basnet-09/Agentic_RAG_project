# %% [markdown]
# ## Data Ingestion

# %% [markdown]
# ### Document datastructure

# %%
from langchain_core.documents import Document

# %%
pip install langchain
# Out:
# Requirement already satisfied: langchain in c:\agentic_rag\venv\lib\site-packages (1.2.10)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in c:\agentic_rag\venv\lib\site-packages (from langchain) (1.2.14)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.8 in c:\agentic_rag\venv\lib\site-packages (from langchain) (1.0.9)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\agentic_rag\venv\lib\site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\agentic_rag\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\agentic_rag\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.7.6)
# Requirement already satisfied: packaging>=23.2.0 in c:\agentic_rag\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\agentic_rag\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\agentic_rag\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\agentic_rag\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\agentic_rag\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.14.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in c:\agentic_rag\venv\lib\site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (4.0.0)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.8 in c:\agentic_rag\venv\lib\site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (1.0.8)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\agentic_rag\venv\lib\site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (0.3.8)
# Requirement already satisfied: xxhash>=3.5.0 in c:\agentic_rag\venv\lib\site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (3.6.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\agentic_rag\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\agentic_rag\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\agentic_rag\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\agentic_rag\venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (3.0.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\agentic_rag\venv\lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.8->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in c:\agentic_rag\venv\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in c:\agentic_rag\venv\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\agentic_rag\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\agentic_rag\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\agentic_rag\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (0.25.0)
# Requirement already satisfied: anyio in c:\agentic_rag\venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (4.12.1)
# Requirement already satisfied: certifi in c:\agentic_rag\venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\agentic_rag\venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\agentic_rag\venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\agentic_rag\venv\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\agentic_rag\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\agentic_rag\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.6.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
doc = Document(page_content="This is the main page content I am using to create the RAG",
                metadata={"source": "Example.txt",
                          "pages":1,
                          "author":"Manish Basnet",
                          "date_created":"2024-06-01"}
                          
                          )
doc
# Out:
# Document(metadata={'source': 'Example.txt', 'pages': 1, 'author': 'Manish Basnet', 'date_created': '2024-06-01'}, page_content='This is the main page content I am using to create the RAG')

# %%
#Create a simple txt file
import os

os.makedirs("data/text_files", exist_ok=True)

# %%
sample_text={
    "./data/text_files/python_intro.txt": """Python 🐍 is a versatile, high-level programming language known for its readability and simple syntax, which often looks like plain English. It is a favorite for everything from web development to data science and artificial intelligence 🤖.

Let’s build a basic introduction file together. We can start by looking at three fundamental concepts. Which of these would you like to explore first?

Variables and Data Types: How Python stores information like names (strings), ages (integers), or prices (floats).

Control Flow: Using if statements and loops to let your code make decisions and repeat tasks.

Functions: Creating reusable blocks of code to keep your scripts organized and efficient."""
}

for file_path, content in sample_text.items():
    with open(file_path, "w", encoding="utf-8") as f:
        f.write(content)    

print("Sample text file created successfully!")
# Out:
# Sample text file created successfully!

# %%
sample_text={
    "./data/text_files/machine_learning.txt": """Machine learning 🤖 is a subset of artificial intelligence that focuses on building systems that learn from data to make predictions or decisions. Instead of following explicit rules (like a traditional program), these systems identify patterns within vast amounts of information.To build your introductory text for machine learning, we can explore these three core areas. I'll ask guiding questions along the way to help you fill in the details:

The Three Main Types: Understanding supervised learning (learning with labels), unsupervised learning (finding hidden patterns), and reinforcement learning (learning through trial and error).

The Training Process: How we take raw data, split it into training and testing sets, and help the model "learn" from its mistakes.

Real-World Applications: Exploring how machine learning powers things you use every day, like recommendation engines, spam filters, or image recognition."""
}

for file_path, content in sample_text.items():
    with open(file_path, "w", encoding="utf-8") as f:
        f.write(content)    

print("Sample text file created successfully!")
# Out:
# Sample text file created successfully!

# %%
### Text Loader
from langchain_community.document_loaders import TextLoader
loader = TextLoader("../data/text_files/python_intro.txt",encoding="utf-8")
loader
document = loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python 🐍 is a versatile, high-level programming language known for its readability and simple syntax, which often looks like plain English. It is a favorite for everything from web development to data science and artificial intelligence 🤖.\n\nLet’s build a basic introduction file together. We can start by looking at three fundamental concepts. Which of these would you like to explore first?\n\nVariables and Data Types: How Python stores information like names (strings), ages (integers), or prices (floats).\n\nControl Flow: Using if statements and loops to let your code make decisions and repeat tasks.\n\nFunctions: Creating reusable blocks of code to keep your scripts organized and efficient.')]

# %%
### Directory Loader
from langchain_community.document_loaders import DirectoryLoader

#load all the text files form the directory
dir_loader = DirectoryLoader(
    "../data/text_files", #Directory to load files from
    glob="**/*.txt", #Pattern to match all text files in the directory and subdirectories
    loader_cls=TextLoader, #Specify the loader class to use for each file
    loader_kwargs ={"encoding":"utf-8"}, #Additional arguments to pass to the loader class
    show_progress=False #Whether to display a progress bar during loading
)

documents = dir_loader.load()
print(documents)
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\machine_learning.txt'}, page_content='Machine learning 🤖 is a subset of artificial intelligence that focuses on building systems that learn from data to make predictions or decisions. Instead of following explicit rules (like a traditional program), these systems identify patterns within vast amounts of information.To build your introductory text for machine learning, we can explore these three core areas. I\'ll ask guiding questions along the way to help you fill in the details:\n\nThe Three Main Types: Understanding supervised learning (learning with labels), unsupervised learning (finding hidden patterns), and reinforcement learning (learning through trial and error).\n\nThe Training Process: How we take raw data, split it into training and testing sets, and help the model "learn" from its mistakes.\n\nReal-World Applications: Exploring how machine learning powers things you use every day, like recommendation engines, spam filters, or image recognition.'), Document(metadata={'source': '..\\data\\text_files\\python_intro.txt'}, page_content='Python 🐍 is a versatile, high-level programming language known for its readability and simple syntax, which often looks like plain English. It is a favorite for everything from web development to data science and artificial intelligence 🤖.\n\nLet’s build a basic introduction file together. We can start by looking at three fundamental concepts. Which of these would you like to explore first?\n\nVariables and Data Types: How Python stores information like names (strings), ages (integers), or prices (floats).\n\nControl Flow: Using if statements and loops to let your code make decisions and repeat tasks.\n\nFunctions: Creating reusable blocks of code to keep your scripts organized and efficient.')]

# %%
### Directory Loader
from langchain_community.document_loaders import PyPDFLoader,PyMuPDFLoader

#load all the text files form the directory
dir_loader = DirectoryLoader(
    "../data/pdf", #Directory to load files from
    glob="**/*.pdf", #Pattern to match all pdf files in the directory and subdirectories
    loader_cls=PyMuPDFLoader, #Specify the loader class to use for each file
    show_progress=False #Whether to display a progress bar during loading
)

pdf_documents = dir_loader.load()
print(pdf_documents)
# Out:
# [Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-01-31T21:58:09+05:45', 'source': '..\\data\\pdf\\Project Proposal A-M-S.pdf', 'file_path': '..\\data\\pdf\\Project Proposal A-M-S.pdf', 'total_pages': 16, 'format': 'PDF 1.7', 'title': '', 'author': 'Ashutosh Adhikari', 'subject': '', 'keywords': '', 'moddate': '2026-01-31T21:58:09+05:45', 'trapped': '', 'modDate': "D:20260131215809+05'45'", 'creationDate': "D:20260131215809+05'45'", 'page': 0}, page_content='TRIBHUVAN UNIVERSITY \nInstitute of Science and Technology \n \n \nA Project Proposal \nOn \n"E-Voting System" \n \nSubmitted to \nDepartment of Statistics and Computer Science \nPatan Multiple Campus \n \nIn partial fulfillement of the requriments for Bachelor Degree in Computer \nscience and Information Technology \n \n \nSubmitted By: \nAshutosh Adhikari (79010020) \nManish Basnet (79010054) \nSnehal Sigdel (79010119) \n \nDate: \n1st Feb 2026'), Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-01-31T21:58:09+05:45', 'source': '..\\data\\pdf\\Project Proposal A-M-S.pdf', 'file_path': '..\\data\\pdf\\Project Proposal A-M-S.pdf', 'total_pages': 16, 'format': 'PDF 1.7', 'title': '', 'author': 'Ashutosh Adhikari', 'subject': '', 'keywords': '', 'moddate': '2026-01-31T21:58:09+05:45', 'trapped': '', 'modDate': "D:20260131215809+05'45'", 'creationDate': "D:20260131215809+05'45'", 'page': 1}, page_content='ii \n \nTable of Contents \n1. \nIntroduction .................................................................................................................. 1 \n2. \nProblem Statement ....................................................................................................... 1 \n3. \nObjectives .................................................................................................................... 1 \n4. \nMethodology ................................................................................................................ 2 \n4.1. \nRequirement Identification .................................................................................. 2 \n4.1.1. Study of Existing System ................................................................................. 2 \n4.1.2. Literature Review............................................................................................. 2 \n4.1.3. Requirement Analysis ...................................................................................... 3 \n4.2. \nFeasibility Study .................................................................................................. 5 \n4.2.1. Technical Feasibility ........................................................................................ 5 \n4.2.2. Operational Feasibility ..................................................................................... 5 \n4.2.3. Economic Feasibility ....................................................................................... 5 \n4.2.4. Schedule Feasibility ......................................................................................... 6 \n4.3. \nHigh Level Design of System .............................................................................. 6 \n4.3.1. Methodology of the proposed system .............................................................. 6 \n4.3.2. System Flowchart............................................................................................. 8 \n4.3.3. Use Case diagram ............................................................................................ 9 \n4.3.4. Description of algorithm ................................................................................ 10 \n5. \nExpected Outcome ..................................................................................................... 11 \n6. \nReferences ....................................................................................................... ...

# %%
type(pdf_documents[0])
# Out:
# langchain_core.documents.base.Document
